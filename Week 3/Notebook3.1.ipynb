# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 3.1: Practice with Data Collections*
#
# <a href="https://colab.research.google.com/github/harmanani/AAI614/blob/main/Week%203/Notebook3.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# Source: Scraping with Python http://shop.oreilly.com/product/0636920034391.do

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

# Configure SSL context to ignore certificate verification
ssl._create_default_https_context = ssl._create_unverified_context

# Function to scrape a webpage and print different types of data
def scrape_wikipedia_page(url):
    try:
        # Open the URL
        html = urlopen(url)
        # Parse the HTML using BeautifulSoup
        bs = BeautifulSoup(html, 'html.parser')

        # Extract all links (anchor tags) with an 'href' attribute
        print("Extracting all hyperlinks:")
        for link in bs.find_all('a'):
            if 'href' in link.attrs:
                href = link.attrs['href']
                # Check if it's a Wikipedia link (internal link)
                if href.startswith('/wiki/'):
                    print(f"Internal link: https://en.wikipedia.org{href}")
                else:
                    print(f"External link: {href}")

        # Extract all image URLs
        print("\nExtracting all image sources:")
        for img in bs.find_all('img'):
            if 'src' in img.attrs:
                print(img.attrs['src'])

        # Extract all paragraph texts
        print("\nExtracting all paragraph texts:")
        for paragraph in bs.find_all('p'):
            print(paragraph.get_text())

        # Extract specific content using CSS selectors (e.g., headers)
        print("\nExtracting all headings (h1, h2, h3):")
        for header in bs.select('h1, h2, h3'):
            print(header.get_text())

    except Exception as e:
        # Print an error message if something goes wrong
        print(f"An error occurred: {e}")

# URL to scrape
url = 'http://en.wikipedia.org/wiki/Kevin_Bacon'

# Call the scraping function with the specified URL
scrape_wikipedia_page(url)
# Out:
# Extracting all hyperlinks:
# External link: #main-content
# External link: http://www.sfda.gov.sa/en
# External link: #
# External link: /en/overview
# External link: /en/authority-establishment
# External link: /en/authority-membership
# External link: /en/authority-activities
# External link: /en/authority-management
# External link: /en/board-of-directors
# External link: /en/sfda-in-vision
# External link: /en/sfda-ntp
# External link: /en/sfda-hstp
# External link: /en/sfda-nidlp
# External link: /en/vision-and-mission
# External link: /en/authority-values
# External link: /en/annual-report
# External link: /en/career-vision-and-mission
# External link: /en/career-general-goals
# External link: #
# External link: /en/lists-categories?tags=All
# External link: /en/lists-categories?tags=46
# External link: /en/lists-categories?tags=1
# External link: /en/lists-categories?tags=2
# External link: /en/lists-categories?tags=3
# External link: /en/lists-categories?tags=4
# External link: /en/lists-categories?tags=6
# External link: /en/lists-categories?tags=7
# External link: /en/lists-categories?tags=47
# External link: /en/lists-categories?tags=5
# External link: /en/lists-categories?tags=50
# External link: /en/lists-categories?tags=69
# External link: #
# External link: #nav-all
# External link: #nav-Authority
# External link: #nav-food
# External link: #nav-medicin
# External link: #nav-electronic
# External link: #animal-food
# External link: #pesticides
# External link: #laboratories
# External link: #cosmetics
# External link: #smoke-trees
# External link: #Halal
# External link: #Nutrition
# External link: /en/regulations?tags=All
# External link: /en/Guide?tags=All
# External link: /en/forms?tags=All
# External link: /en/circulars?tags=All
# External link: /en/faq?tags=All
# External link: /en/regulations?tags=46
# External link: /en/Guide?tags=46
# External link: /en/forms?tags=46
# External link: /en/circulars?tags=46
# External link: /en/faq?tags=46
# External link: /en/overview-food
# External link: /en/regulations?tags=1
# External link: /en/Guide?tags=1
# External link: /en/forms?tags=1
# External link: /en/circulars?tags=1
# External link: /en/faq?tags=1
# External link: /en/evaluation-program
# External link: /en/decisions
# External link: /en/overview-drugs
# External link: /en/regulations?tags=2
# External link: /en/Guide?tags=2
# External link: /en/drugs_circulars_withdrawal
# External link: /en/forms?tags=2
# External link: /en/circulars?tags=2
# External link: /en/faq?tags=2
# External link: /en/sector-list
# External link: /en/overview-medical
# External link: /en/regulations?tags=3
# External link: /en/Guide?tags=3
# External link: /en/forms?tags=3
# External link: /en/circulars?tags=3
# External link: /en/faq?tags=3
# External link: /en/medical_devices_studies?tags=3
# External link: /en/regulations?tags=4
# External link: /en/Guide?tags=4
# External link: /en/forms?tags=4
# External link: /en/circulars?tags=4
# External link: /en/faq?tags=4
# External link: /en/regulations?tags=5
# External link: /en/Guide?tags=5
# External link: /en/forms?tags=5
# External link: /en/circulars?tags=5
# External link: /en/faq?tags=5
# External link: /en/regulations?tags=6
# External link: /en/Guide?tags=6
# External link: /en/forms?tags=6
# External link: /en/circulars?tags=6
# External link: /en/faq?tags=6
# External link: /en/regulations?tags=7
# External link: /en/Guide?tags=7
# External link: /en/forms?tags=7
# External link: /en/circulars?tags=7
# External link: /en/faq?tags=7
# External link: /en/regulations?tags=47
# External link: /en/Guide?tags=47
# External link: /en/forms?tags=47
# External link: /en/circulars?tags=47
# External link: /en/faq?tags=47
# External link: /en/halal
# External link: /en/regulations?tags=50
# External link: /en/Guide?tags=50
# External link: /en/forms?tags=50
# External link: /en/circulars?tags=50
# External link: /en/faq?tags=50
# External link: /en/overview-nnc
# External link: /en/scientific-reports-and-statements
# External link: /en/regulations?tags=69
# External link: /en/Guide?tags=69
# External link: #
# External link: /en/awarenesscampaign
# External link: /en/awarenessarticle
# External link: /en/paracetamol-calculator
# External link: #
# External link: /en/news
# External link: /en/rumours
# External link: /en/warnings?tags=All
# External link: /en/calendar
# External link: /en/workshop
# External link: /en/mediacentre
# External link: /en/podcasts
# External link: /en/eforms
# External link: /en/scientific-magazines-and-articles
# External link: #
# External link: /en/eservices?tags=All
# External link: /en/eservices?tags=46
# External link: /en/eservices?tags=1
# External link: /en/eservices?tags=2
# External link: /en/eservices?tags=3
# External link: /en/eservices?tags=4
# External link: /en/eservices?tags=6
# External link: /en/eservices?tags=7
# External link: /en/eservices?tags=47
# External link: /en/eservices?tags=5
# External link: /en/eservices?tags=50
# External link: /en/eservices?tags=69
# External link: https://vision2030.gov.sa/en
# External link: /en/contact-us
# External link: /en/nnjzha
# External link: /en/open-data
# External link: #
# External link: #
# External link: /ar/drugs-list
# External link: http://www.sfda.gov.sa/en
# External link: #
# External link: /en/overview
# External link: /en/authority-establishment
# External link: /en/authority-membership
# External link: /en/authority-activities
# External link: /en/authority-management
# External link: /en/board-of-directors
# External link: /en/sfda-in-vision
# External link: /en/sfda-ntp
# External link: /en/sfda-hstp
# External link: /en/sfda-nidlp
# External link: /en/vision-and-mission
# External link: /en/authority-values
# External link: /en/annual-report
# External link: /en/career-vision-and-mission
# External link: /en/career-general-goals
# External link: #
# External link: /en/lists-categories?tags=All
# External link: /en/lists-categories?tags=46
# External link: /en/lists-categories?tags=1
# External link: /en/lists-categories?tags=2
# External link: /en/lists-categories?tags=3
# External link: /en/lists-categories?tags=4
# External link: /en/lists-categories?tags=6
# External link: /en/lists-categories?tags=7
# External link: /en/lists-categories?tags=47
# External link: /en/lists-categories?tags=5
# External link: /en/lists-categories?tags=50
# External link: /en/lists-categories?tags=69
# External link: #
# External link: #nav-all
# External link: #nav-Authority
# External link: #nav-food
# External link: #nav-medicin
# External link: #nav-electronic
# External link: #animal-food
# External link: #pesticides
# External link: #laboratories
# External link: #cosmetics
# External link: #smoke-trees
# External link: #Halal
# External link: #Nutrition
# External link: /en/regulations?tags=All
# External link: /en/Guide?tags=All
# External link: /en/forms?tags=All
# External link: /en/circulars?tags=All
# External link: /en/faq?tags=All
# External link: /en/regulations?tags=46
# External link: /en/Guide?tags=46
# External link: /en/forms?tags=46
# External link: /en/circulars?tags=46
# External link: /en/faq?tags=46
# External link: /en/overview-food
# External link: /en/regulations?tags=1
# External link: /en/Guide?tags=1
# External link: /en/forms?tags=1
# External link: /en/circulars?tags=1
# External link: /en/faq?tags=1
# External link: /en/evaluation-program
# External link: /en/decisions
# External link: /en/overview-drugs
# External link: /en/regulations?tags=2
# External link: /en/Guide?tags=2
# External link: /en/drugs_circulars_withdrawal
# External link: /en/forms?tags=2
# External link: /en/circulars?tags=2
# External link: /en/faq?tags=2
# External link: /en/sector-list
# External link: /en/overview-medical
# External link: /en/regulations?tags=3
# External link: /en/Guide?tags=3
# External link: /en/forms?tags=3
# External link: /en/circulars?tags=3
# External link: /en/faq?tags=3
# External link: /en/medical_devices_studies?tags=3
# External link: /en/regulations?tags=4
# External link: /en/Guide?tags=4
# External link: /en/forms?tags=4
# External link: /en/circulars?tags=4
# External link: /en/faq?tags=4
# External link: /en/regulations?tags=5
# External link: /en/Guide?tags=5
# External link: /en/forms?tags=5
# External link: /en/circulars?tags=5
# External link: /en/faq?tags=5
# External link: /en/regulations?tags=6
# External link: /en/Guide?tags=6
# External link: /en/forms?tags=6
# External link: /en/circulars?tags=6
# External link: /en/faq?tags=6
# External link: /en/regulations?tags=7
# External link: /en/Guide?tags=7
# External link: /en/forms?tags=7
# External link: /en/circulars?tags=7
# External link: /en/faq?tags=7
# External link: /en/regulations?tags=47
# External link: /en/Guide?tags=47
# External link: /en/forms?tags=47
# External link: /en/circulars?tags=47
# External link: /en/faq?tags=47
# External link: /en/halal
# External link: /en/regulations?tags=50
# External link: /en/Guide?tags=50
# External link: /en/forms?tags=50
# External link: /en/circulars?tags=50
# External link: /en/faq?tags=50
# External link: /en/overview-nnc
# External link: /en/scientific-reports-and-statements
# External link: /en/regulations?tags=69
# External link: /en/Guide?tags=69
# External link: #
# External link: /en/awarenesscampaign
# External link: /en/awarenessarticle
# External link: /en/calculators
# External link: #
# External link: /en/news
# External link: /en/rumours
# External link: /en/warnings?tags=All
# External link: /en/calendar
# External link: /en/workshop
# External link: /en/mediacentre
# External link: /en/podcasts
# External link: /en/eforms
# External link: /en/scientific-magazines-and-articles
# External link: #
# External link: /en/eservices?tags=All
# External link: /en/eservices?tags=46
# External link: /en/eservices?tags=1
# External link: /en/eservices?tags=2
# External link: /en/eservices?tags=3
# External link: /en/eservices?tags=4
# External link: /en/eservices?tags=6
# External link: /en/eservices?tags=7
# External link: /en/eservices?tags=47
# External link: /en/eservices?tags=5
# External link: /en/eservices?tags=50
# External link: /en/eservices?tags=69
# External link: https://vision2030.gov.sa/en
# External link: /index.php/en
# External link: https://apps.apple.com/us/app/%D8%B7%D9%85%D9%86%D9%8A/id1483589368
# External link: https://play.google.com/store/apps/details?id=sfda.tamini&hl=ar
# External link: /en/vet-drugs
# External link: /en/herbal-drugs
# External link: /GetDrugList.php
# External link:
# External link:
# External link: /en/sitemap
# External link: /en/overview
# External link: /en/form/contact-us
# External link: /en/form/ask-sfda
# External link: /en/rss
# External link: https://careers.sfda.gov.sa/
# External link: /en/faq
# External link: /en/awardsandachievements
# External link: https://remote.sfda.gov.sa/dana-na/auth/url_default/welcome.cgi
# External link: /en/customer-charter
# External link: /en/quality-of-reception
# External link: https://www.vision2030.gov.sa/ar/
# External link: https://www.my.gov.sa/wps/portal/snp/main
# External link: https://open.data.gov.sa/ar/home
# External link: https://www.moh.gov.sa/Pages/Default.aspx
# External link: https://istitlaa.ncc.gov.sa/ar/health/sfda/Pages/default.aspx
# External link: https://eparticipation.my.gov.sa/
# External link: https://momah.gov.sa/ar
# External link: https://www.mewa.gov.sa/ar/Pages/default.aspx
# External link: https://mc.gov.sa/ar/pages/default.aspx
# External link: https://business.sa/
# External link: https://apps.apple.com/us/app/%D8%BA%D8%B0%D8%A7%D8%A1-%D9%88%D8%AF%D9%88%D8%A7%D8%A1/id1485253067
# External link: https://play.google.com/store/apps/details?id=sfda.sfdaapp1&hl=ar
# External link: /en/rss.xml
# External link: https://ae.linkedin.com/company/sfda
# External link: https://www.youtube.com/channel/UC2-qPKHVpCDhJJIky-SkkJg
# External link: https://www.snapchat.com/add/saudi_fda
# External link: http://instagram.com/saudi_fda
# External link: https://www.facebook.com/SaudiFDA/
# External link: https://twitter.com/saudi_fda
# External link: /en/privacy-policy
# External link: /en/terms-of-use
# External link: /en/rules-of-use
#
# Extracting all image sources:
# /themes/custom/sfda/assets/images/sfda_logo_colored.svg
# /themes/custom/sfda/assets/images/sfda_logo_colored.svg
# /themes/custom/sfda/assets/images/icons/menu-all.svg
# /themes/custom/sfda/assets/images/icons/sfda-blue-icon.svg
# /themes/custom/sfda/assets/images/icons/fruit.svg
# /themes/custom/sfda/assets/images/icons/syringe.svg
# /themes/custom/sfda/assets/images/icons/operating.svg
# /themes/custom/sfda/assets/images/icons/animal-food.svg
# /themes/custom/sfda/assets/images/icons/pesticide.svg
# /themes/custom/sfda/assets/images/icons/laboratory.svg
# /themes/custom/sfda/assets/images/icons/makeup2.svg
# /themes/custom/sfda/assets/images/icons/smoking.svg
# /themes/custom/sfda/assets/images/icons/halal_logo.svg
# /themes/custom/sfda/assets/images/icons/NNC.svg
# /themes/custom/sfda/assets/images/icons/menu-all.svg
# /themes/custom/sfda/assets/images/icons/sfda-blue-icon.svg
# /themes/custom/sfda/assets/images/icons/fruit.svg
# /themes/custom/sfda/assets/images/icons/syringe.svg
# /themes/custom/sfda/assets/images/icons/operating.svg
# /themes/custom/sfda/assets/images/icons/animal-food.svg
# /themes/custom/sfda/assets/images/icons/pesticide.svg
# /themes/custom/sfda/assets/images/icons/laboratory.svg
# /themes/custom/sfda/assets/images/icons/makeup2.svg
# /themes/custom/sfda/assets/images/icons/smoking.svg
# /themes/custom/sfda/assets/images/icons/halal_logo.svg
# /themes/custom/sfda/assets/images/icons/NNC.svg
# /themes/custom/sfda/assets/images/icons/idea_(1).svg
# /themes/custom/sfda/assets/images/icons/magazine.svg
# /themes/custom/sfda/assets/images/calories-calculator2.svg
# /themes/custom/sfda/assets/images/icons/worlwide.svg
# /themes/custom/sfda/assets/images/icons/idea.svg
# /themes/custom/sfda/assets/images/icons/magazine.svg
# /themes/custom/sfda/assets/images/icons/calendar.svg
# /themes/custom/sfda/assets/images/icons/group.svg
# /themes/custom/sfda/assets/images/icons/film.svg
# /themes/custom/sfda/assets/images/icons/microphone.svg
# /themes/custom/sfda/assets/images/icons/magazine.svg
# /themes/custom/sfda/assets/images/icons/magazine.svg
# /themes/custom/sfda/assets/images/icons/menu-all.svg
# /themes/custom/sfda/assets/images/icons/sfda-blue-icon.svg
# /themes/custom/sfda/assets/images/icons/fruit.svg
# /themes/custom/sfda/assets/images/icons/syringe.svg
# /themes/custom/sfda/assets/images/icons/operating.svg
# /themes/custom/sfda/assets/images/icons/animal-food.svg
# /themes/custom/sfda/assets/images/icons/pesticide.svg
# /themes/custom/sfda/assets/images/icons/laboratory.svg
# /themes/custom/sfda/assets/images/icons/makeup2.svg
# /themes/custom/sfda/assets/images/icons/smoking.svg
# /themes/custom/sfda/assets/images/icons/halal_logo.svg
# /themes/custom/sfda/assets/images/icons/NNC.svg
# /themes/custom/sfda/assets/images/2030_colored.svg
# /themes/custom/sfda/assets/images/icons/gear-2.svg
# /themes/custom/sfda/assets/images/sfda_logo_white.svg
# /themes/custom/sfda/assets/images/hajj_logo_3.png
# /themes/custom/sfda/assets/images/icons/menu-all.svg
# /themes/custom/sfda/assets/images/icons/sfda-blue-icon.svg
# /themes/custom/sfda/assets/images/icons/fruit.svg
# /themes/custom/sfda/assets/images/icons/syringe.svg
# /themes/custom/sfda/assets/images/icons/operating.svg
# /themes/custom/sfda/assets/images/icons/animal-food.svg
# /themes/custom/sfda/assets/images/icons/pesticide.svg
# /themes/custom/sfda/assets/images/icons/laboratory.svg
# /themes/custom/sfda/assets/images/icons/makeup2.svg
# /themes/custom/sfda/assets/images/icons/smoking.svg
# /themes/custom/sfda/assets/images/icons/halal_logo.svg
# /themes/custom/sfda/assets/images/icons/NNC.svg
# /themes/custom/sfda/assets/images/icons/menu-all.svg
# /themes/custom/sfda/assets/images/icons/sfda-blue-icon.svg
# /themes/custom/sfda/assets/images/icons/fruit.svg
# /themes/custom/sfda/assets/images/icons/syringe.svg
# /themes/custom/sfda/assets/images/icons/operating.svg
# /themes/custom/sfda/assets/images/icons/animal-food.svg
# /themes/custom/sfda/assets/images/icons/pesticide.svg
# /themes/custom/sfda/assets/images/icons/laboratory.svg
# /themes/custom/sfda/assets/images/icons/makeup2.svg
# /themes/custom/sfda/assets/images/icons/smoking.svg
# /themes/custom/sfda/assets/images/icons/halal_logo.svg
# /themes/custom/sfda/assets/images/icons/NNC.svg
# /themes/custom/sfda/assets/images/icons/idea_(1).svg
# /themes/custom/sfda/assets/images/icons/magazine.svg
# /themes/custom/sfda/assets/images/calories-calculator2.svg
# /themes/custom/sfda/assets/images/icons/worlwide.svg
# /themes/custom/sfda/assets/images/icons/idea.svg
# /themes/custom/sfda/assets/images/icons/magazine.svg
# /themes/custom/sfda/assets/images/icons/calendar.svg
# /themes/custom/sfda/assets/images/icons/group.svg
# /themes/custom/sfda/assets/images/icons/film.svg
# /themes/custom/sfda/assets/images/icons/microphone.svg
# /themes/custom/sfda/assets/images/icons/magazine.svg
# /themes/custom/sfda/assets/images/icons/magazine.svg
# /themes/custom/sfda/assets/images/icons/menu-all.svg
# /themes/custom/sfda/assets/images/icons/sfda-blue-icon.svg
# /themes/custom/sfda/assets/images/icons/fruit.svg
# /themes/custom/sfda/assets/images/icons/syringe.svg
# /themes/custom/sfda/assets/images/icons/operating.svg
# /themes/custom/sfda/assets/images/icons/animal-food.svg
# /themes/custom/sfda/assets/images/icons/pesticide.svg
# /themes/custom/sfda/assets/images/icons/laboratory.svg
# /themes/custom/sfda/assets/images/icons/makeup2.svg
# /themes/custom/sfda/assets/images/icons/smoking.svg
# /themes/custom/sfda/assets/images/icons/halal_logo.svg
# /themes/custom/sfda/assets/images/icons/NNC.svg
# /themes/custom/sfda/assets/images/2030_white.svg
# /themes/custom/sfda/assets/images/icons/tameniapp.png
# /themes/custom/sfda/assets/images/icons/appstore-en.png
# /themes/custom/sfda/assets/images/icons/google-play-badge.png
# /themes/custom/sfda/assets/images/icons/drugs-white.svg
# /themes/custom/sfda/assets/images/icons/vaccine-blue.svg
# /themes/custom/sfda/assets/images/icons/vaccine-white.svg
# /themes/custom/sfda/assets/images/icons/mortar-blue.svg
# /themes/custom/sfda/assets/images/icons/mortar-white.svg
# /themes/custom/sfda/assets/images/icons/search.svg
# /themes/custom/sfda/assets/images/sfda_logo_colored.svg
# /themes/custom/sfda/assets/images/SGS_ISO_20000_TCL_HR.jpg
# /themes/custom/sfda/assets/images/SGS_ISO_22301_TCL_HR.jpg
#
# Extracting all paragraph texts:
# Font Resize
#
#                                                     Contrast
#
# Do you have a madicine that you would like to know more about? Download Tameni
# drugs
# Veterinary drugs
# herbal, health drugs and vitamins
# روابط مهمة
# All Rights Reserved © Saudi Food and Drug Authority ©
# 				2024
#
#
# Extracting all headings (h1, h2, h3):
#
#
#
# Drugs List
#
#
#
# Drugs List
# In your opinion, how reliable are these data??

# %% [markdown]
# ## Retrieving Articles Only

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    print(link.attrs['href'])

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    print(link.attrs['href'])

# %% [markdown]
# ## Random Walk

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now().strftime('%s'))
def getLinks(articleUrl):
    html = urlopen(f'http://en.wikipedia.org{articleUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Kevin_Bacon')
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)

# %% [markdown]
# ## Recursively crawling an entire site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    html = urlopen(f'http://en.wikipedia.org{pageUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')

# %% [markdown]
# ## Collecting Data Across an Entire Site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    html = urlopen(f'http://en.wikipedia.org{pageUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text())
        #mw-parser-output
        bodyContent = bs.find('div', {'id':'bodyContent'}).find_all('p')
        if len(bodyContent):
            print(bodyContent[0])
        print(bs.find(id='ca-edit').find('a').attrs['href'])
    except AttributeError:
        print('This page is missing something! Continuing.')

    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print('-'*20)
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('/wiki/General-purpose_programming_language')

# %% [markdown]
# ## Crawling across the Internet

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bs, url):
    netloc = urlparse(url).netloc
    scheme = urlparse(url).scheme
    internalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc == '':
            internalLinks.add(f'{scheme}://{netloc}/{link.attrs["href"].strip("/")}')
        elif parsed.netloc == netloc:
            internalLinks.add(link.attrs['href'])
    return list(internalLinks)

#Retrieves a list of all external links found on a page
def getExternalLinks(bs, url):
    netloc = urlparse(url).netloc
    externalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc != '' and parsed.netloc != netloc:
            externalLinks.add(link.attrs['href'])
    return list(externalLinks)

def getRandomExternalLink(startingPage):
    bs = BeautifulSoup(urlopen(startingPage), 'html.parser')
    externalLinks = getExternalLinks(bs, startingPage)
    if not len(externalLinks):
        print('No external links, looking around the site for one')
        internalLinks = getInternalLinks(bs, startingPage)
        return getRandomExternalLink(random.choice(internalLinks))
    else:
        return random.choice(externalLinks)

def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print(f'Random external link is: {externalLink}')
    followExternalOnly(externalLink)


followExternalOnly('https://www.oreilly.com/')

# %% [markdown]
# ## Collect all External Links from a Site

# %%
# Collects a list of all external URLs found on the site
allExtLinks = []
allIntLinks = []


def getAllExternalLinks(url):
    bs = BeautifulSoup(urlopen(url), 'html.parser')
    internalLinks = getInternalLinks(bs, url)
    externalLinks = getExternalLinks(bs, url)
    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.append(link)
            print(link)

    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.append(link)
            getAllExternalLinks(link)


allIntLinks.append('https://oreilly.com')
getAllExternalLinks('https://www.oreilly.com/')
